# %%
from sympy import *
from sympy.abc import u, v, e
from sympy import init_printing
import sympy
init_printing() 

from scipy.special import comb
from IPython.display import display

# %%
# calcs prob of player winning game with n people in it (incl. them)
# assuming player beats all with prob. p
def get_win_probs(n, p):
    probs = [None for _ in range(n)]
    probs[1] = 1
    probs[2] = p
    
    for i in range(3, n):
        new_prob = Rational(1, i) * Pow(p, i-1) # picked as prince and wins
        
        for j in range(1, i): # prob of transitioning to j-player game
            # not picked as prince and prince beats  other people
            new_prob += Rational(i-1, i) * p * Rational(1, int(2**(i-2))) * int(comb(i-2, j-1)) * probs[j]
            
        probs[i] = new_prob.expand()
            
    return probs

# %%
n = 5
u = Rational(1,2) + e
v = Rational(1,2) - e
wprobs = get_win_probs(n, u)
for i in range(3, n):
    print(i)
    display(wprobs[i])
# Out:
# 3
#    2
# 2⋅e        1
# ──── + e + ─
#  3         3
# 4
#    3
# 3⋅e     2   29⋅e   1
# ──── + e  + ──── + ─
#  8           32    4

# %%
# calcs prob of player winning game assuming
# 1. game starts with n players total, they are not prince
# 2. prince throws to them and doesn't beat everyone else
# 3. prince wins each match with prob. p0, player wins each match with prob p
# Base case is n = 3, which is just (1-p0)p (prince loses)

# I checked for n = 4 and it's right. 
def get_probs(n, p, p0):
    win_probs = get_win_probs(n, p)
    probs = [None for _ in range(n)]
    probs[3] = (1 - p0) * p
    
    for i in range(4, n):
        new_prob = 0
        for j in range(2, i): # prob of transitioning from i-player game to j-player game
            to_beat = max(0, i-j-1)
            new_prob += int(comb(i-2, to_beat)) * (p0 ** to_beat) * (1-p0) ** (i-2-to_beat) * win_probs[j]
            
        probs[i] = new_prob.expand()
    return probs

# %%
n = 7
u = Rational(1,2) + e
v = Rational(1,2) - e
uprobs = get_probs(n, u, v)
vprobs = get_probs(n, v, v)
for i in range(3, n):
    print(i)
    display(uprobs[i])
    #display(vprobs[i])
    #display(vprobs[i].evalf(subs={e:'0.5'}))
# Out:
# 3
#          2
# (e + 1/2)
# 4
#    4    3    2
# 2⋅e    e    e    13⋅e   1
# ──── - ── + ── + ──── + ─
#  3     3    2     12    3
# 5
#    6      5       4       3       2
# 3⋅e    7⋅e    27⋅e    13⋅e    23⋅e    237⋅e   11
# ──── - ──── + ───── + ───── + ───── + ───── + ──
#  8      16      16      32     128     256    32
# 6
#     8       7        6        5        4         3        2
# 19⋅e    49⋅e    459⋅e    849⋅e    429⋅e    3429⋅e    961⋅e    7709⋅e   13
# ───── - ───── + ────── - ────── + ────── + ─────── + ────── + ────── + ──
#   80     160     320      640      256       2560     5120    10240    40

# %%
n = 5
u = Rational(1,2) + e
v = Rational(1,2) - e
probs = get_probs(n, u, v)
for i in range(3, n):
    print(i)
    display(probs[i])
# Out:
# 3
#          2
# (e + 1/2)
# 4
#    4    3    2
# 2⋅e    e    e    13⋅e   1
# ──── - ── + ── + ──── + ─
#  3     3    2     12    3

# %%
def get_diffs(n, u, v, fake=False):
    diffs = [None for _ in range(n)]
    
    higher = get_probs(n, u, v)
    if fake:
        lower = get_probs(n, v, v)
    else:
        lower = get_probs(n, v, u)
    
    for i in range(3, n):
        diffs[i] = (higher[i] - lower[i]).expand()
    return diffs

# %%
n = 10
u = Rational(1,2) + e
v = Rational(1,2) - e
diffs = get_diffs(n, u, v, True)
for i in range(3, n):
    print(i)
    eq = (diffs[i]).expand()
    display(eq)
    print(eq.evalf(subs={e:'0.1'}))
    print(eq.evalf(subs={e:'0.2'}))
    print(eq.evalf(subs={e:'0.3'}))
    print(eq.evalf(subs={e:'0.4'}))
    print(eq.evalf(subs={e:'0.45'}))
    print(eq.evalf(subs={e:'0.5'}))
# Out:
# 3
#    2
# 2⋅e  + e
# 0.120000000000000
# 0.280000000000000
# 0.480000000000000
# 0.720000000000000
# 0.855000000000000
# 1.00000000000000
# 4
#      3      2   3⋅e
# - 2⋅e  + 2⋅e  + ───
#                  2
# 0.168000000000000
# 0.364000000000000
# 0.576000000000000
# 0.792000000000000
# 0.897750000000000
# 1.00000000000000
# 5
#    6      5       4       3       2
# 3⋅e    9⋅e    19⋅e    51⋅e    87⋅e    221⋅e
# ──── + ──── + ───── - ───── + ───── + ─────
#  4      8       8       16      64     128
# 0.183312000000000
# 0.378395500000000
# 0.576768000000000
# 0.779517000000000
# 0.886142707031250
# 1.00000000000000
# 6
#       7    6       5       4        3       2
#   25⋅e    e    35⋅e    11⋅e    835⋅e    81⋅e    1849⋅e
# - ───── - ── + ───── + ───── - ────── + ───── + ──────
#     16    8      64      2      256      128     1024
# 0.184188000000000
# 0.369298562500000
# 0.556032000000000
# 0.758093625000000
# 0.872218439208984
# 1.00000000000000
# 7
#      10         9         8         7         6          5          4
# 275⋅e     1375⋅e    4775⋅e    1875⋅e    3241⋅e    13375⋅e    65555⋅e    127015
# ─────── + ─────── + ─────── - ─────── - ─────── - ──────── + ──────── - ──────
#   768       1536      1536      1024      3072      6144       8192       4915
#
#   3         2
# ⋅e    3025⋅e    710621⋅e
# ─── + ─────── + ────────
# 2      196608    393216
# 0.179067255000000
# 0.353407546269531
# 0.532357120000000
# 0.737514621210938
# 0.859277074622984
# 1.00000000000000
# 8
#          11          10          9          8         7         6            5
#   68471⋅e     82213⋅e     57385⋅e    31675⋅e    9827⋅e    5459⋅e    1573769⋅e
# - ───────── - ───────── - ──────── + ──────── + ─────── - ─────── - ──────────
#     57344       57344      32768       4096      65536     65536      262144
#
#             4             3           2
#    2146395⋅e    22834675⋅e    942479⋅e    14845755⋅e
#  + ────────── - ─────────── - ───────── + ──────────
#      229376       14680064     2097152     8388608
# 0.171801338326071
# 0.336596386485164
# 0.510122636434286
# 0.718834694005377
# 0.847451891721884
# 1.00000000000000
# 9
#         14            13             12            11             10
# 532755⋅e     3729285⋅e     15574511⋅e     9072993⋅e     54788075⋅e     6993373
# ────────── + ─────────── + ──────────── + ─────────── - ──────────── - ───────
#  2097152       4194304       4194304        8388608       33554432       67108
#
#     9              8              7               6                5
# 73⋅e    345603521⋅e    194804223⋅e    1836456237⋅e    10415367205⋅e    1032148
# ───── + ──────────── + ──────────── + ───────────── - ────────────── + ───────
# 864       33554432       67108864       536870912       1073741824       10737
#
#       4              3               2
# 9471⋅e    979678479⋅e    6658873781⋅e    29452838557⋅e
# ─────── - ──────────── - ───────────── + ─────────────
# 41824      2147483648      8589934592     17179869184
# 0.164098002606897
# 0.320771961821212
# 0.490114109049600
# 0.702007648778908
# 0.836690121983433
# 1.00000000000000

# %%
def get_Gs(n, u, v):
    Gs = [None for _ in range(n)]
    diffs = get_diffs(n, u, v)
    
    # assumed u = 1/2 + eps
    Gs[3] = (Rational(1, 3) * u * diffs[3]).expand()
    
    for i in range(4, n):
        
        G = Rational(1, i) * u * diffs[i]
        
        for j in range(3, i-1):
            G += Rational(i-2, i) * int(comb(i-3, i-j+1)) * Rational(1, 2 ** (i-3)) * Gs[j] 
            
        Gs[i] = G.expand()
    
    return Gs

# %%
# Quick visual inspection shows that these terms are maximized when e = 0.5.
# (Proof for n=4 to 8? Only have to do it for up to 8 anyway.)

n = 10
u = Rational(1,2) + e
v = Rational(1,2) - e
Gs = get_Gs(n, u, v)
for i in range(3, n):
    print(i)
    display(Gs[i])
    display(Gs[i].evalf(subs={e:'0.5'}))
# Out:
# 3
#    2
# 2⋅e    e
# ──── + ─
#  3     3
# 0.333333333333333
# 4
#    4    3       2
#   e    e    13⋅e    13⋅e
# - ── - ── + ───── + ────
#   6    12     24     48
# 0.250000000000000
# 5
#      6      5       4       3        2
#   7⋅e    7⋅e    13⋅e    13⋅e    237⋅e    237⋅e
# - ──── - ──── + ───── + ───── + ────── + ─────
#    40     80      80     160     640      1280
# 0.200000000000000
# 6
#       8       7        6        5         4         3         2
#   49⋅e    49⋅e    283⋅e    283⋅e    1143⋅e    1143⋅e    7709⋅e    7709⋅e
# - ───── - ───── - ────── - ────── + ─────── + ─────── + ─────── + ──────
#    480     960     640      1280      2560      5120     30720    61440
# 0.166666666666667
# 7
#        10        9         8         7          6          5         4
#   619⋅e     619⋅e    4099⋅e    4099⋅e    11351⋅e    11351⋅e    4549⋅e    4549⋅
# - ─────── - ────── - ─────── - ─────── - ──────── - ──────── + ─────── + ─────
#    10752    21504     10752     21504     28672      57344       8192     1638
#
#  3           2
# e    489437⋅e    489437⋅e
# ── + ───────── + ────────
# 4     2752512    5505024
# 0.142857142857143
# 8
#          12          11           10           9            8            7
#   17669⋅e     17669⋅e     487167⋅e     487167⋅e    3054561⋅e    3054561⋅e    1
# - ───────── - ───────── - ────────── - ───────── - ────────── - ────────── - ─
#     458752      917504     1835008      3670016     3670016      7340032
#
#         6            5             4             3             2
# 081575⋅e    1081575⋅e    63191799⋅e    63191799⋅e    63025821⋅e    63025821⋅e
# ───────── - ────────── + ─────────── + ─────────── + ─────────── + ──────────
# 14680064     29360128     117440512     234881024     469762048    939524096
# 0.125000000000000
# 9
#            14            13            12            11              10
#   1084511⋅e     1084511⋅e     5046883⋅e     5046883⋅e     437477989⋅e     4374
# - ─────────── - ─────────── - ─────────── - ─────────── - ───────────── - ────
#     37748736      75497472      25165824      50331648      603979776      120
#
#        9              8              7               6               5
# 77989⋅e    231424529⋅e    231424529⋅e    1002403373⋅e    1002403373⋅e    29939
# ──────── - ──────────── - ──────────── + ───────────── + ───────────── + ─────
# 7959552     201326592      402653184       3221225472      6442450944      644
#
#        4               3                2
# 03477⋅e    2993903477⋅e    16635045533⋅e    16635045533⋅e
# ──────── + ───────────── + ────────────── + ─────────────
# 2450944     12884901888     154618822656     309237645312
# 0.111111111111111

# %%
def required(n):
    want = Rational(n-3, n)
    
    have = 0
    
    for k in range(3, n):
        have += Rational(n-2, n) * Rational(1, 2 ** (n-3)) * int(comb(n-3, k-2))
        
    need = want/have
        
    return need.expand()

# %%
for n in range(4, 20):
    print(n)
    print(required(n))
    print(float(required(n)))
    print(float(n-3)/(n-2))
    print()
# Out:
# 4
# 1.0
# 0.5
#
# 5
# 0.8888888888888888
# 0.6666666666666666
#
# 6
# 0.8571428571428571
# 0.75
#
# 7
# 0.8533333333333334
# 0.8
#
# 8
# 0.8602150537634409
# 0.8333333333333334
#
# 9
# 0.8707482993197279
# 0.8571428571428571
#
# 10
# 0.8818897637795275
# 0.875
#
# 11
# 0.8923747276688453
# 0.8888888888888888
#
# 12
# 0.901761252446184
# 0.9
#
# 13
# 0.909979561005954
# 0.9090909090909091
#
# 14
# 0.9171144764696304
# 0.9166666666666666
#
# 15
# 0.9233023386869541
# 0.9230769230769231
#
# 16
# 0.9286847934143747
# 0.9285714285714286
#
# 17
# 0.9333903029563165
# 0.9333333333333333
#
# 18
# 0.9375286111026337
# 0.9375
#
# 19
# 0.9411908320206086
# 0.9411764705882353
